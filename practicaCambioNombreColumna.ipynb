# %% [markdown]
# <a href="https://colab.research.google.com/github/valentingracia/codingDojoDC/blob/main/practicaCambioNombreColumna.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Alumno: Valentin Gracia
# **Data Science Coding Dojo G1**

# %% [markdown]
# Montamos el drive junto con el dataframe

# %%
from google.colab import drive
#drive.mount('/content/drive')

import pandas as pd

filename = '/content/drive/MyDrive/Coding Dojo/Semana2/RailsToTrails_National_Count_Data_week.xlsx'
bike_df = pd.read_excel(filename)
print(bike_df.head())
print(bike_df.columns)
#bike_df.info
# Out:
#   Timeframe    Week of  ...  Unnamed: 8  Unnamed: 9
# 0    Week 1 2020-12-30  ...         NaN         NaN
# 1    Week 2 2020-01-06  ...         NaN         NaN
# 2    Week 3 2020-01-13  ...         NaN         NaN
# 3    Week 4 2020-01-20  ...         NaN         NaN
# 4    Week 5 2020-01-27  ...         NaN         NaN
#
# [5 rows x 10 columns]
# Index(['Timeframe', 'Week of', ' 2019 counts (31 counters)',
#        ' 2020 counts (31 counters)', '2021 Counts', 'Change 2019-2020',
#        'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9'],
#       dtype='object')

# %%
bike_df.rename(columns={"Unnamed: 6":"percent_change"})
# Out:
#    Timeframe    Week of  ...  Unnamed: 8  Unnamed: 9
# 0     Week 1 2020-12-30  ...         NaN         NaN
# 1     Week 2 2020-01-06  ...         NaN         NaN
# 2     Week 3 2020-01-13  ...         NaN         NaN
# 3     Week 4 2020-01-20  ...         NaN         NaN
# 4     Week 5 2020-01-27  ...         NaN         NaN
# 5     Week 6 2020-02-03  ...         NaN         NaN
# 6     Week 7 2020-02-10  ...         NaN         NaN
# 7     Week 8 2020-02-17  ...         NaN         NaN
# 8     Week 9 2020-02-24  ...         NaN         NaN
# 9    Week 10 2020-03-02  ...         NaN         NaN
# 10   Week 11 2020-03-09  ...         NaN         NaN
# 11   Week 12 2020-03-16  ...         NaN         NaN
# 12   Week 13 2020-03-23  ...         NaN         NaN
# 13   Week 14 2020-03-30  ...         NaN         NaN
# 14   Week 15 2020-04-06  ...         NaN         NaN
# 15   Week 16 2020-04-13  ...         NaN         NaN
# 16   Week 17 2020-04-20  ...         NaN         NaN
# ...

# %% [markdown]
# Reporte Nan

# %%
bike_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Timeframe                   52 non-null     object
#  1   Week of                     52 non-null     datetime64[ns]
#  2    2019 counts (31 counters)  52 non-null     int64
#  3    2020 counts (31 counters)  52 non-null     int64
#  4   2021 Counts                 0 non-null      float64
#  5   Change 2019-2020            52 non-null     float64
#  6   Unnamed: 6                  52 non-null     float64
#  7   Unnamed: 7                  0 non-null      float64
#  8   Unnamed: 8                  1 non-null      float64
#  9   Unnamed: 9                  1 non-null      float64
# dtypes: datetime64[ns](1), float64(6), int64(2), object(1)
# memory usage: 4.2+ KB

# %% [markdown]
# Llenar 2021 Count con "0"

# %%
#bike_df=bike_df.loc[:, '2021 Counts'].fillna(0)
bike_df['2021 Counts'].fillna(0,inplace=True)
bike_df
# Out:
#    Timeframe    Week of  ...  Unnamed: 8  Unnamed: 9
# 0     Week 1 2020-12-30  ...         NaN         NaN
# 1     Week 2 2020-01-06  ...         NaN         NaN
# 2     Week 3 2020-01-13  ...         NaN         NaN
# 3     Week 4 2020-01-20  ...         NaN         NaN
# 4     Week 5 2020-01-27  ...         NaN         NaN
# 5     Week 6 2020-02-03  ...         NaN         NaN
# 6     Week 7 2020-02-10  ...         NaN         NaN
# 7     Week 8 2020-02-17  ...         NaN         NaN
# 8     Week 9 2020-02-24  ...         NaN         NaN
# 9    Week 10 2020-03-02  ...         NaN         NaN
# 10   Week 11 2020-03-09  ...         NaN         NaN
# 11   Week 12 2020-03-16  ...         NaN         NaN
# 12   Week 13 2020-03-23  ...         NaN         NaN
# 13   Week 14 2020-03-30  ...         NaN         NaN
# 14   Week 15 2020-04-06  ...         NaN         NaN
# 15   Week 16 2020-04-13  ...         NaN         NaN
# 16   Week 17 2020-04-20  ...         NaN         NaN
# ...

# %% [markdown]
# cambiar nombre columna " 2019 counts (31 counters)"

# %%
bike_df.rename(columns={" 2019 counts (31 counters)":"conteos_2019"})
# Out:
#    Timeframe    Week of  conteos_2019  ...  Unnamed: 7  Unnamed: 8  Unnamed: 9
# 0     Week 1 2020-12-30        167679  ...         NaN         NaN         NaN
# 1     Week 2 2020-01-06         82340  ...         NaN         NaN         NaN
# 2     Week 3 2020-01-13         62315  ...         NaN         NaN         NaN
# 3     Week 4 2020-01-20         75801  ...         NaN         NaN         NaN
# 4     Week 5 2020-01-27         75841  ...         NaN         NaN         NaN
# 5     Week 6 2020-02-03         79780  ...         NaN         NaN         NaN
# 6     Week 7 2020-02-10         65732  ...         NaN         NaN         NaN
# 7     Week 8 2020-02-17         69492  ...         NaN         NaN         NaN
# 8     Week 9 2020-02-24         85688  ...         NaN         NaN         NaN
# 9    Week 10 2020-03-02         84512  ...         NaN         NaN         NaN
# 10   Week 11 2020-03-09        107995  ...         NaN         NaN         NaN
# ...
