# %% [markdown]
# <a href="https://colab.research.google.com/github/valentingracia/codingDojoDC/blob/main/visualization_chart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Alumno Valentin Gracia

# %% [markdown]
# librerias e importaciones

# %%
import pandas as pd
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt


debt_df=pd.read_excel("/content/drive/MyDrive/Coding Dojo/Semana3/US GDP vs Debt.xlsx")
debt_df.rename(columns={"Gross Domestic Product ($mil)":"GDP","Total Public Debt ($mil)":"TPD"},inplace=True)
debt_df.head(3)
# Out:
#      Quarter      GDP  TPD
# 0 1947-01-01  243.164  NaN
# 1 1947-04-01  245.968  NaN
# 2 1947-07-01  249.585  NaN

# %% [markdown]
# cleansing

# %%
print(debt_df.info());
debt_df.drop(debt_df.tail(1).index,inplace=True)
debt_df.fillna(0,inplace=True)
debt_df.info();
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 295 entries, 0 to 294
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Quarter  295 non-null    datetime64[ns]
#  1   GDP      295 non-null    float64
#  2   TPD      218 non-null    float64
# dtypes: datetime64[ns](1), float64(2)
# memory usage: 7.0 KB
# None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 294 entries, 0 to 293
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Quarter  294 non-null    datetime64[ns]
#  1   GDP      294 non-null    float64
#  2   TPD      294 non-null    float64
# dtypes: datetime64[ns](1), float64(2)
# memory usage: 9.2 KB

# %%
plt.style.use("seaborn")
#print(list(debt_df["Quarter"].values))
#print(list(debt_df["TPD"].values))
#plt.show()
#series


fig,ax1 = plt.subplots()

ax2 = ax1.twinx()


ax1.plot(list(debt_df["Quarter"].values),(list(debt_df["GDP"].values)),c="green",label="Gross Domestic Product")
ax2.plot(list(debt_df["Quarter"].values),(list(debt_df["TPD"].values)),c="tomato",label="Total Public Debt ($mil)")

#accesory
ax2.legend(loc="lower right")
ax1.legend(loc=0)


plt.title("GDP vs National Debt Overtime")


ax1.set_xlabel("Years",fontsize="15")
ax1.set_ylabel("gdp in mmusd",c="green")
ax2.set_ylabel("debt in mmusd",c="tomato")

ax1.yaxis.set_major_formatter(mpl.ticker.StrMethodFormatter('{x:,.0f}'))
ax2.yaxis.set_major_formatter(mpl.ticker.StrMethodFormatter('{x:,.0f}'))
#x.get_xaxis().get_major_formatter().set_scientific(False)




ax1.set_ylim(0, max(list(debt_df["GDP"].values))*1.02)
ax2.set_ylim(0,max(list(debt_df["TPD"].values))*1.02)



fig.tight_layout()

plt.show()
