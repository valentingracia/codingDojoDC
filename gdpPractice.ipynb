# %% [markdown]
# <a href="https://colab.research.google.com/github/valentingracia/codingDojoDC/blob/main/gdpPractice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Alumno : Valentin Gracia
# Data Science G1

# %%
import pandas as pd
gdp_df=pd.read_csv("/content/drive/MyDrive/Coding Dojo/Semana2/GDP.csv",skiprows=3)
#print(gdp_df.head())
gdp_df.info()
#gdp_df.dropna(inplace=True)
#gdp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 264 entries, 0 to 263
# Data columns (total 63 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    264 non-null    object
#  1   Country Code    264 non-null    object
#  2   Indicator Name  264 non-null    object
#  3   Indicator Code  264 non-null    object
#  4   1960            133 non-null    float64
#  5   1961            133 non-null    float64
#  6   1962            135 non-null    float64
#  7   1963            135 non-null    float64
#  8   1964            135 non-null    float64
#  9   1965            145 non-null    float64
#  10  1966            146 non-null    float64
#  11  1967            149 non-null    float64
#  12  1968            153 non-null    float64
#  13  1969            153 non-null    float64
#  14  1970            162 non-null    float64
#  15  1971            163 non-null    float64
#  16  1972            163 non-null    float64
# ...

# %%
gdp_df.groupby(["Country Name","Country Code"])["1960","1961","1962","1963","1964","1965","1966","1967","1968"].mean()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                                          1960  ...          1968
# Country Name       Country Code                ...
# Afghanistan        AFG           5.377778e+08  ...  1.373333e+09
# Albania            ALB                    NaN  ...           NaN
# Algeria            DZA           2.723649e+09  ...  3.852116e+09
# American Samoa     ASM                    NaN  ...           NaN
# Andorra            AND                    NaN  ...           NaN
# ...                                       ...  ...           ...
# West Bank and Gaza PSE                    NaN  ...           NaN
# World              WLD           1.365887e+12  ...  2.441774e+12
# Yemen, Rep.        YEM                    NaN  ...           NaN
# ...
